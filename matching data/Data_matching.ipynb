# %%
# !pip install csvdedupe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 83 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 105 kB 36.0 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 39.1 MB/s
# ...
#      |████████████████████████████████| 55 kB 794 kB/s
# ...
#      |████████████████████████████████| 194 kB 40.5 MB/s
# ...
#      |████████████████████████████████| 71 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 150 kB 59.8 MB/s
# ...
#      |████████████████████████████████| 583 kB 75.8 MB/s
# ...
#      |████████████████████████████████| 253 kB 51.4 MB/s
# ...
#      |████████████████████████████████| 251 kB 62.8 MB/s
# ...
#      |████████████████████████████████| 972 kB 59.6 MB/s
# ...
#      |████████████████████████████████| 239 kB 51.5 MB/s
# ...

# %%
# !csvlink /content/CellPhones.csv /content/NguyenKim.csv \ 
            --field_names title producer ram memory \ 
            --output_file output.csv  
##!csvlink /content/CellPhones.csv /content/NguyenKim.csv \ #đầu vào là 2 file
#            --field_names title producer ram memory \ #dùng các trường title ,producer,raw,memory để đánh giá matching
#            --output_file output.csv  # đầu ra file matching,đặt tên
# Out:
# title : samsung galaxy a52
# producer : samsung
# ram : 8 gb
# memory : 128 gb
#
# title : samsung galaxy s20+ xanh
# producer : samsung
# ram : 8 gb
# memory : 128 gb
#
# 0/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# n
# title : samsung galaxy a72
# producer : samsung
# ram : 8 gb
# memory : 256 gb
#
# title : samsung galaxy s20+ xanh
# producer : samsung
# ram : 8 gb
# memory : 128 gb
#
# 0/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# title : samsung galaxy a72
# producer : samsung
# ram : 8 gb
# memory : 256 gb
#
# title : samsung galaxy s20+ đen
# producer : samsung
# ram : 8 gb
# memory : 128 gb
#
# 0/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# title : samsung galaxy a52
# producer : samsung
# ram : 8 gb
# memory : 128 gb
#
# ...
